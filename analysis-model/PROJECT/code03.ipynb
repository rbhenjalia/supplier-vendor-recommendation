# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ast import literal_eval
from collections import defaultdict
# %matplotlib inline
import random
from sklearn.preprocessing import MinMaxScaler

# %%
category = pd.read_csv('D:/DST/Category.csv')
category = category[['MultiLink','Best_Seller','Best_Seller_Rating']]
brand = pd.read_csv('D:/DST/Brand.csv')
brand = brand[['Brand','Best_Seller','Best_Seller_Rating']]
product = pd.read_csv('D:/DST/Product.csv')
product = product[['Product','Best_Seller','Best_Seller_Rating']]
price = pd.read_csv('D:/DST/Price.csv')
price = price[['Product','Best_Seller','Best_Seller_Rating']]
Data = pd.read_csv('D:/DST/FinalData.csv')
Data = Data.loc[:, Data.columns != 'Unnamed: 0']

# %%
Data
# Out:
#                                        MultiLink  \
# 0                              Video Games Deals
# 1                                     Headphones
# 2                               Drives & Storage
# 3                                     Components
# 4               Janitorial & Sanitation Supplies
# 5                                       Monitors
# 6                                       Monitors
# 7                                  Refrigerators
# 8                   Office Supplies & Stationery
# 9                                     Components
# 10                                      Monitors
# 11                                      Monitors
# 12                          Home Audio & Theater
# 13      Musical Instruments & Professional Audio
# 14                             Video Games Deals
# 15              Janitorial & Sanitation Supplies
# 16                   All Computers & Accessories
# 17                                  DSLR Cameras
# ...
