# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ast import literal_eval
from collections import defaultdict
# %matplotlib inline
import random
from sklearn.preprocessing import MinMaxScaler

# %%
SCR = pd.read_csv('D:/DST/Seller_Category_Ratings.csv')
SPR = pd.read_csv('D:/DST/Seller_Products_Ratings.csv')
SBR = pd.read_csv('D:/DST/Seller_Brand_Ratings.csv')
SWR = pd.read_csv('D:/DST/Seller_Wise_Ratings.csv')
Data = pd.read_csv('D:/DST/FinalData.csv')

Data = Data[['MultiLink', 'Product', 'Brand', 'Seller', 'Price','FeedBack_Rating', 'Product_Rating', 'Packaging_Rating','Courier_Rating']]
SCR = SCR[['Seller', 'MultiLink', 'FeedBack_Rating','Courier_Rating', 'Product_Rating', 'Packaging_Rating', 'ALL_OVER']]
SPR = SPR[['Seller', 'Product', 'FeedBack_Rating', 'Courier_Rating','Product_Rating', 'Packaging_Rating', 'ALL_OVER']]
SBR = SBR[['Seller', 'Brand', 'FeedBack_Rating', 'Courier_Rating','Product_Rating', 'Packaging_Rating', 'ALL_OVER']]
SWR = SWR[['Seller', 'FeedBack_Rating', 'Courier_Rating','Product_Rating', 'Packaging_Rating', 'ALL_OVER']]

# %%
dr = pd.DataFrame(SPR.groupby('Product')['Seller'].count()).reset_index()
ser = pd.Series(dr['Product'])
newSet = pd.DataFrame(dr['Product'])

def Best_Seller(product,data):
    ALL_OVER = data[data['Product'] == product].sort_values(by='ALL_OVER',ascending=False).reset_index(drop=True)
    Best_Seller_ALL_OVER = ALL_OVER['Seller'][0]
    Best_Seller_ALL_OVER_Rating = ALL_OVER['ALL_OVER'][0]
    
    FeedBack_Rating = data[data['Product'] == product].sort_values(by='FeedBack_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_FeedBack_Rating = FeedBack_Rating['Seller'][0]
    Best_Seller_FeedBack_Rating_Rating = FeedBack_Rating['FeedBack_Rating'][0]
    
    Product_Rating = data[data['Product'] == product].sort_values(by='Product_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Product_Rating = Product_Rating['Seller'][0]
    Best_Seller_Product_Rating_Rating = Product_Rating['Product_Rating'][0]
    
    Packaging_Rating = data[data['Product'] == product].sort_values(by='Packaging_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Packaging_Rating = Packaging_Rating['Seller'][0]
    Best_Seller_Packaging_Rating_Rating = Packaging_Rating['Packaging_Rating'][0]
    
    Courier_Rating = data[data['Product'] == product].sort_values(by='Courier_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Courier_Rating = Courier_Rating['Seller'][0]
    Best_Seller_Courier_Rating_Rating = Courier_Rating['Courier_Rating'][0]
    
    return Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating


Best_Seller_ALL_OVER_x = []
Best_Seller_ALL_OVER_Rating_x = []
Best_Seller_FeedBack_Rating_x = []
Best_Seller_FeedBack_Rating_Rating_x = []
Best_Seller_Product_Rating_x = []
Best_Seller_Product_Rating_Rating_x = []
Best_Seller_Packaging_Rating_x = []
Best_Seller_Packaging_Rating_Rating_x = []
Best_Seller_Courier_Rating_x = []
Best_Seller_Courier_Rating_Rating_x = []


for item in ser:
    Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating = Best_Seller(item,SPR)
    Best_Seller_ALL_OVER_x.append(Best_Seller_ALL_OVER)
    Best_Seller_ALL_OVER_Rating_x.append(Best_Seller_ALL_OVER_Rating)
    Best_Seller_FeedBack_Rating_x.append(Best_Seller_FeedBack_Rating)
    Best_Seller_FeedBack_Rating_Rating_x.append(Best_Seller_FeedBack_Rating_Rating)
    Best_Seller_Product_Rating_x.append(Best_Seller_Product_Rating)
    Best_Seller_Product_Rating_Rating_x.append(Best_Seller_Product_Rating_Rating)
    Best_Seller_Packaging_Rating_x.append(Best_Seller_Packaging_Rating)
    Best_Seller_Packaging_Rating_Rating_x.append(Best_Seller_Packaging_Rating_Rating)
    Best_Seller_Courier_Rating_x.append(Best_Seller_Courier_Rating)
    Best_Seller_Courier_Rating_Rating_x.append(Best_Seller_Courier_Rating_Rating)

newSet['Best_Seller_ALL_OVER'] = pd.DataFrame(Best_Seller_ALL_OVER_x)
newSet['Best_Seller_ALL_OVER_Rating'] = pd.DataFrame(Best_Seller_ALL_OVER_Rating_x)
newSet['Best_Seller_FeedBack_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_x)
newSet['Best_Seller_FeedBack_Rating_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_Rating_x)
newSet['Best_Seller_Product_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_x)
newSet['Best_Seller_Product_Rating_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_Rating_x)
newSet['Best_Seller_Packaging_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_x)
newSet['Best_Seller_Packaging_Rating_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_Rating_x)
newSet['Best_Seller_Courier_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_x)
newSet['Best_Seller_Courier_Rating_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_Rating_x)

# %%
newSet.to_csv('D:/DST/Product_Wise_BestSellers.csv')

# %%
dr = pd.DataFrame(SBR.groupby('Brand')['Seller'].count()).reset_index()
ser = pd.Series(dr['Brand'])
newSet = pd.DataFrame(dr['Brand'])

def Best_Seller(entity,data):
    ALL_OVER = data[data['Brand'] == product].sort_values(by='ALL_OVER',ascending=False).reset_index(drop=True)
    Best_Seller_ALL_OVER = ALL_OVER['Seller'][0]
    Best_Seller_ALL_OVER_Rating = ALL_OVER['ALL_OVER'][0]
    
    FeedBack_Rating = data[data['Brand'] == product].sort_values(by='FeedBack_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_FeedBack_Rating = FeedBack_Rating['Seller'][0]
    Best_Seller_FeedBack_Rating_Rating = FeedBack_Rating['FeedBack_Rating'][0]
    
    Product_Rating = data[data['Brand'] == product].sort_values(by='Product_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Product_Rating = Product_Rating['Seller'][0]
    Best_Seller_Product_Rating_Rating = Product_Rating['Product_Rating'][0]
    
    Packaging_Rating = data[data['Brand'] == product].sort_values(by='Packaging_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Packaging_Rating = Packaging_Rating['Seller'][0]
    Best_Seller_Packaging_Rating_Rating = Packaging_Rating['Packaging_Rating'][0]
    
    Courier_Rating = data[data['Brand'] == product].sort_values(by='Courier_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Courier_Rating = Courier_Rating['Seller'][0]
    Best_Seller_Courier_Rating_Rating = Courier_Rating['Courier_Rating'][0]
    
    return Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating


Best_Seller_ALL_OVER_x = []
Best_Seller_ALL_OVER_Rating_x = []
Best_Seller_FeedBack_Rating_x = []
Best_Seller_FeedBack_Rating_Rating_x = []
Best_Seller_Product_Rating_x = []
Best_Seller_Product_Rating_Rating_x = []
Best_Seller_Packaging_Rating_x = []
Best_Seller_Packaging_Rating_Rating_x = []
Best_Seller_Courier_Rating_x = []
Best_Seller_Courier_Rating_Rating_x = []


for item in ser:
    Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating = Best_Seller(item,SBR)
    Best_Seller_ALL_OVER_x.append(Best_Seller_ALL_OVER)
    Best_Seller_ALL_OVER_Rating_x.append(Best_Seller_ALL_OVER_Rating)
    Best_Seller_FeedBack_Rating_x.append(Best_Seller_FeedBack_Rating)
    Best_Seller_FeedBack_Rating_Rating_x.append(Best_Seller_FeedBack_Rating_Rating)
    Best_Seller_Product_Rating_x.append(Best_Seller_Product_Rating)
    Best_Seller_Product_Rating_Rating_x.append(Best_Seller_Product_Rating_Rating)
    Best_Seller_Packaging_Rating_x.append(Best_Seller_Packaging_Rating)
    Best_Seller_Packaging_Rating_Rating_x.append(Best_Seller_Packaging_Rating_Rating)
    Best_Seller_Courier_Rating_x.append(Best_Seller_Courier_Rating)
    Best_Seller_Courier_Rating_Rating_x.append(Best_Seller_Courier_Rating_Rating)

newSet['Best_Seller_ALL_OVER'] = pd.DataFrame(Best_Seller_ALL_OVER_x)
newSet['Best_Seller_ALL_OVER_Rating'] = pd.DataFrame(Best_Seller_ALL_OVER_Rating_x)
newSet['Best_Seller_FeedBack_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_x)
newSet['Best_Seller_FeedBack_Rating_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_Rating_x)
newSet['Best_Seller_Product_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_x)
newSet['Best_Seller_Product_Rating_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_Rating_x)
newSet['Best_Seller_Packaging_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_x)
newSet['Best_Seller_Packaging_Rating_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_Rating_x)
newSet['Best_Seller_Courier_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_x)
newSet['Best_Seller_Courier_Rating_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_Rating_x)

newSet.to_csv('D:/DST/Brand_Wise_BestSellers.csv')

# %%
dr = pd.DataFrame(SCR.groupby('MultiLink')['Seller'].count()).reset_index()
ser = pd.Series(dr['MultiLink'])
newSet = pd.DataFrame(dr['MultiLink'])

def Best_Seller(product,data):
    ALL_OVER = data[data['MultiLink'] == product].sort_values(by='ALL_OVER',ascending=False).reset_index(drop=True)
    Best_Seller_ALL_OVER = ALL_OVER['Seller'][0]
    Best_Seller_ALL_OVER_Rating = ALL_OVER['ALL_OVER'][0]
    
    FeedBack_Rating = data[data['MultiLink'] == product].sort_values(by='FeedBack_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_FeedBack_Rating = FeedBack_Rating['Seller'][0]
    Best_Seller_FeedBack_Rating_Rating = FeedBack_Rating['FeedBack_Rating'][0]
    
    Product_Rating = data[data['MultiLink'] == product].sort_values(by='Product_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Product_Rating = Product_Rating['Seller'][0]
    Best_Seller_Product_Rating_Rating = Product_Rating['Product_Rating'][0]
    
    Packaging_Rating = data[data['MultiLink'] == product].sort_values(by='Packaging_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Packaging_Rating = Packaging_Rating['Seller'][0]
    Best_Seller_Packaging_Rating_Rating = Packaging_Rating['Packaging_Rating'][0]
    
    Courier_Rating = data[data['MultiLink'] == product].sort_values(by='Courier_Rating',ascending=False).reset_index(drop=True)
    Best_Seller_Courier_Rating = Courier_Rating['Seller'][0]
    Best_Seller_Courier_Rating_Rating = Courier_Rating['Courier_Rating'][0]
    
    return Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating


Best_Seller_ALL_OVER_x = []
Best_Seller_ALL_OVER_Rating_x = []
Best_Seller_FeedBack_Rating_x = []
Best_Seller_FeedBack_Rating_Rating_x = []
Best_Seller_Product_Rating_x = []
Best_Seller_Product_Rating_Rating_x = []
Best_Seller_Packaging_Rating_x = []
Best_Seller_Packaging_Rating_Rating_x = []
Best_Seller_Courier_Rating_x = []
Best_Seller_Courier_Rating_Rating_x = []


for item in ser:
    Best_Seller_ALL_OVER, Best_Seller_ALL_OVER_Rating, Best_Seller_FeedBack_Rating, Best_Seller_FeedBack_Rating_Rating, Best_Seller_Product_Rating, Best_Seller_Product_Rating_Rating, Best_Seller_Packaging_Rating, Best_Seller_Packaging_Rating_Rating, Best_Seller_Courier_Rating, Best_Seller_Courier_Rating_Rating = Best_Seller(item,SCR)
    Best_Seller_ALL_OVER_x.append(Best_Seller_ALL_OVER)
    Best_Seller_ALL_OVER_Rating_x.append(Best_Seller_ALL_OVER_Rating)
    Best_Seller_FeedBack_Rating_x.append(Best_Seller_FeedBack_Rating)
    Best_Seller_FeedBack_Rating_Rating_x.append(Best_Seller_FeedBack_Rating_Rating)
    Best_Seller_Product_Rating_x.append(Best_Seller_Product_Rating)
    Best_Seller_Product_Rating_Rating_x.append(Best_Seller_Product_Rating_Rating)
    Best_Seller_Packaging_Rating_x.append(Best_Seller_Packaging_Rating)
    Best_Seller_Packaging_Rating_Rating_x.append(Best_Seller_Packaging_Rating_Rating)
    Best_Seller_Courier_Rating_x.append(Best_Seller_Courier_Rating)
    Best_Seller_Courier_Rating_Rating_x.append(Best_Seller_Courier_Rating_Rating)

newSet['Best_Seller_ALL_OVER'] = pd.DataFrame(Best_Seller_ALL_OVER_x)
newSet['Best_Seller_ALL_OVER_Rating'] = pd.DataFrame(Best_Seller_ALL_OVER_Rating_x)
newSet['Best_Seller_FeedBack_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_x)
newSet['Best_Seller_FeedBack_Rating_Rating'] = pd.DataFrame(Best_Seller_FeedBack_Rating_Rating_x)
newSet['Best_Seller_Product_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_x)
newSet['Best_Seller_Product_Rating_Rating'] = pd.DataFrame(Best_Seller_Product_Rating_Rating_x)
newSet['Best_Seller_Packaging_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_x)
newSet['Best_Seller_Packaging_Rating_Rating'] = pd.DataFrame(Best_Seller_Packaging_Rating_Rating_x)
newSet['Best_Seller_Courier_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_x)
newSet['Best_Seller_Courier_Rating_Rating'] = pd.DataFrame(Best_Seller_Courier_Rating_Rating_x)

newSet.to_csv('D:/DST/Category_Wise_BestSellers.csv')
