# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ast import literal_eval
from collections import defaultdict
# %matplotlib inline
import random
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('D:\Final Project\DST\FinalData.csv')

# %%
data = data[['MultiLink', 'Product', 'Brand', 'Seller', 'Price','FeedBack_Rating', 'Product_Rating', 'Packaging_Rating','Courier_Rating']]
data.shape
# Out:
# (119986, 9)

# %%
data['Product_Rating'].hist(bins=70)

# %%
data['Price'].hist(bins=70)

# %%
data['FeedBack_Rating'].hist(bins=70)

# %%
data['Packaging_Rating'].hist(bins=70)

# %%
data['Courier_Rating'].hist(bins=70)

# %%
d1 =  pd.read_csv('D:\Final Project\DST\Stats\CountStats\Sellers_PER_Brand.csv').reset_index()
d1['0'].hist(bins=70)

# %%
d1 =  pd.read_csv('D:\Final Project\DST\Stats\CountStats\Sellers_PER_Category.csv').reset_index()
d1['0'].hist(bins=70)

# %%
d1 =  pd.read_csv('D:\Final Project\DST\Stats\CountStats\Sellers_PER_Product.csv').reset_index()
d1['0'].hist(bins=70)
