# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ast import literal_eval

# %matplotlib inline

# %%
amazon_data1 = pd.read_csv('D:/toy.csv')

# %%
amazon_data1.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
sns.heatmap(amazon_data1.isnull(),yticklabels=False,cbar=False)

# %%
amazon_data1['sellers'] = amazon_data1['sellers'].fillna(value="")

# %%
import json
seller_arr = amazon_data1['sellers']

for string in seller_arr:
    if not string:
        print('\n\n')
        print('NULL STRING')
    else:
        string = string.replace("=>",":")
        dic = json.loads(string)
        dicti = dic['seller']
        print('\n\n')
        print(dicti)
        
        F = {}
        temp =[]
        for i in dicti:
            temp=i.split(“,”)
            F[temp[0]]=temp[1]
# Out:
#   File "<ipython-input-121-e6c9faef8f06>", line 18
#     temp=i.split(“,”)
#                  ^
# SyntaxError: invalid character in identifier
